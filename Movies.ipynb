# %% [markdown]
# ## Introduction

# %% [markdown]
# This Project explores data on Movies in the Box Office for the weekends of 2022. Columns are;
#
# | Columns |
# | ------- |
# | Date    |
# | Occassion; Special weekends or not |
# | Gross Revenue of Top 10 Movies in the weekend |
# | Change in Top 10 Gross Revenue from last weekend |
# | Overall Gross Revenue So far |
# | Overall Gross Revenue in the weekend |
# | Change in Overall Gross Revenue from last weekend |
# | Number of releases that weekend |
# | Top  movie released that weekend |
# | Week Number |

# %% [markdown]
# ### Steps Taken
# 1. Scrape data from the Box Office Website using requests and BeautifulSoup
# 2. Save Data in a CSV
# 3. Clean Data in Python using Pandas and other libraries
# 4. Visualize the **cleaned** data in Power BI

# %% [markdown]
# ## Scrape Data and Save in CSV

# %%
#Import necessary libraries
import requests
from bs4 import BeautifulSoup
import pandas as pd
from datetime import datetime

# %%
#website page containing the data
url = 'https://www.boxofficemojo.com/weekend/by-year/2022/'

# %%
#request data from the website
request = requests.get(url)
content = request.text

# %%
soup = BeautifulSoup(content)

# %%
#find all information that is in rows in a table
rows = soup.find_all('tr')

# %%
#gather the data in the rows in the html table into an actual table
appended_data = []
for row in rows:
    data_row = {}
    data = row.find_all('td')
    if len(data) == 0:
        continue
    if len(data[0].find_all('span')) > 0:
        #special weekend
        data_row['occasion'] = data[0].find_all('span')[0].text
        data_row['date'] = data[0].find_all('a')[0].text
    else:
        #normal weekend
        data_row['occasion'] = ""
        data_row['date'] = data[0].text
    data_row['top10_gross'] = data[1].text
    data_row['top10_gross_change'] = data[2].text
    data_row['overall_gross'] = data[3].text
    data_row['overall_gross_change'] = data[4].text
    data_row['num_releases'] = data[5].text
    data_row['top_release'] = data[6].text
    data_row['week_no'] = data[10].text
    appended_data.append(data_row)
weekend_data = pd.DataFrame(appended_data, columns = ['date','occasion', 'top10_gross', 'top10_gross_change', 'overall_gross', 'overall_gross_change', 'num_releases', 'top_release', 'week_no'])

# %% [markdown]
# ### Make Data Suitable by cleaning and converting to appropriate Date Type

# %%
#check the data
weekend_data.head()
# Out:
#                  date              occasion   top10_gross top10_gross_change  \
# 0  Dec 30-Jan 2, 2023  New Year's long wknd  $134,622,744                  -
# 1  Dec 30-Jan 1, 2023                        $102,074,088              +8.6%
# 2           Dec 23-25                         $93,952,740             -37.9%
# 3           Dec 23-26   Christmas long wknd  $141,716,017                  -
# 4           Dec 16-18     World Cup (Qatar)  $151,354,815            +355.1%
#
#   overall_gross overall_gross_change num_releases               top_release  \
# 0  $136,047,635                    -           39  Avatar: The Way of Water
# 1  $103,224,144                  +9%           41  Avatar: The Way of Water
# 2   $94,711,196               -38.1%           35  Avatar: The Way of Water
# 3  $142,814,390                    -           33  Avatar: The Way of Water
# 4  $152,947,812              +305.6%           50  Avatar: The Way of Water
#
#   week_no
# 0      52
# 1      52
# 2      51
# 3      51
# 4      50

# %%
#to csv
weekend_data.to_csv("weekend_data_boxoffice")

# %%
#load csv
df = pd.read_csv('weekend_data_boxoffice')

# %%
#drop first column
df = df.drop(df.columns[0], axis=1)

# %%
pd.set_option('display.max_rows', None)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 63 entries, 0 to 62
# Data columns (total 9 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   date                  63 non-null     object
#  1   occasion              15 non-null     object
#  2   top10_gross           63 non-null     object
#  3   top10_gross_change    63 non-null     object
#  4   overall_gross         63 non-null     object
#  5   overall_gross_change  63 non-null     object
#  6   num_releases          63 non-null     int64
#  7   top_release           63 non-null     object
#  8   week_no               63 non-null     int64
# dtypes: int64(2), object(7)
# memory usage: 4.6+ KB

# %%
df.columns
# Out:
# Index(['date', 'occasion', 'top10_gross', 'top10_gross_change',
#        'overall_gross', 'overall_gross_change', 'num_releases', 'top_release',
#        'week_no'],
#       dtype='object')

# %%
#overall gross and top 10 gross should change to float
#drop $ sign
df['top10_gross'] = df['top10_gross'].str.replace('$', ' ').str.replace(',', '').astype(float)
df["overall_gross"] = df["overall_gross"].str.replace("$", "").str.replace(",", "").astype(float)
# Out:
# C:\Users\Yahdii\AppData\Local\Temp\ipykernel_23540\2607029925.py:3: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df['top10_gross'] = df['top10_gross'].str.replace('$', ' ').str.replace(',', '').astype(float)
# C:\Users\Yahdii\AppData\Local\Temp\ipykernel_23540\2607029925.py:4: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df["overall_gross"] = df["overall_gross"].str.replace("$", "").str.replace(",", "").astype(float)

# %%
#remove leading and trailing spaces
df = df.applymap(lambda x: x.strip() if isinstance(x, str) else x)

# %%
#change format of number columns
df['overall_gross_change'] = df['overall_gross_change'].str.replace('%', '')
df['top10_gross_change'] = df['top10_gross_change'].str.replace('%','')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 63 entries, 0 to 62
# Data columns (total 9 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   date                  63 non-null     object
#  1   occasion              15 non-null     object
#  2   top10_gross           63 non-null     float64
#  3   top10_gross_change    63 non-null     object
#  4   overall_gross         63 non-null     float64
#  5   overall_gross_change  63 non-null     object
#  6   num_releases          63 non-null     int64
#  7   top_release           63 non-null     object
#  8   week_no               63 non-null     int64
# dtypes: float64(2), int64(2), object(5)
# memory usage: 4.6+ KB

# %%
#convert date to datetime 
df['date'] = df['date'].str.split(' ').str[0]+' '+df['date'].str.split('-').str[1]

# %%
#specific cases dec jan 2,2023, required the dec and , to be removed
cleaned_date_str = df.loc[0, 'date'].replace('Dec', '').replace(',', '')
# Replace the original date string in the DataFrame with the cleaned version
df.loc[0, 'date'] = cleaned_date_str

cleaned_date_str = df.loc[1, 'date'].replace('Dec', '').replace(',', '')
# Replace the original date string in the DataFrame with the cleaned version
df.loc[1, 'date'] = cleaned_date_str

cleaned_date_str = df.loc[18, 'date'].replace('Sep', '').replace(',', '')
df.loc[18, 'date'] = cleaned_date_str

cleaned_date_str = df.loc[43, 'date'].replace('Apr', '').replace(',', '')
df.loc[43, 'date'] = cleaned_date_str

# %%
#add 2022 to the dates without year
df['date'] = df['date'].apply(lambda x: x + " 2022"  if "2023" not in x else x)

# %%
#convert date to datetime format
df['date'] = df['date'].apply(lambda x: datetime.strptime(x, '
# 0                   -    136047635.0                    -            39
# 1                +8.6    103224144.0                   +9            41
# 2               -37.9     94711196.0                -38.1            35
# 3                   -    142814390.0                    -            33
# 4              +355.1    152947812.0               +305.6            50
# 5               -32.4     37708268.0                -28.4            58
# 6               -45.2     52669526.0                -43.8            54
# 7                -9.4     93780231.0                 -6.9            49
# 8                   -    111394577.0                    -            36
# 9                   -    134030714.0                    -            37
# 10              -52.1    100684871.0                -51.9            53
# 11             +283.9    209537723.0               +255.6            51
# 12              -15.2     58930348.0                -13.1            56
# 13              -42.3     67841734.0                -40.3            57
# 14              +51.5    113651016.0                +48.9            58
# 15              +35.2     76347045.0                +29.5            57
# 16                  -     67265387.0                    -            45
# 17               -5.3     58977399.0                 -7.8            67
# 18               +1.8     63993367.0                 +2.5            71
# 19              +29.5     62428984.0                +21.3            72
# 20              +26.8     51459761.0                +19.1            74
# 21              -19.9     43193037.0                -22.4            69
# 22               +2.4     55664136.0                 +6.7            63
# 23                  -     71172772.0                    -            55
# 24              -40.2     52149248.0                -33.9            64
# 25                +25     78931261.0                +20.7            58
# 26                -37     65390115.0                  -29            62
# 27               -6.2     92090558.0                 -5.9            48
# 28              -24.4     97884255.0                -22.5            53
# 29               -5.4    126239585.0                 -4.9            52
# 30              -44.7    132813074.0                -44.3            54
# 31              +25.9    238358457.0                +25.5            50
# 32                  -    223580059.0                    -            40
# 33              +41.4    189927071.0                +41.1            53
# 34              -18.3    134597965.0                -18.2            54
# 35              -23.1    164531244.0                -23.4            56
# 36              +79.4    214852641.0                +76.6            56
# 37              -32.2    121670007.0                -31.3            59
# 38                  -    223364859.0                    -            47
# 39             +144.1    177208035.0               +134.2            50
# 40              -19.7     75659163.0                -17.5            53
# 41              -59.6     91763058.0                -58.7            49
# 42             +252.4    222333899.0               +232.3            45
# 43              -30.7     66904036.0                -28.4            50
# 44              -14.8     93502811.0                -12.8            45
# 45               -9.6    107168534.0                 -9.7            40
# 46                  -    119498996.0                    -            28
# 47                +46    118700008.0                  +43            50
# 48               +2.2     83007169.0                 +1.2            52
# 49                 -2     82040448.0                 -1.7            60
# 50              -19.4     83455041.0                -18.1            58
# 51              -39.2    101939737.0                -38.6            53
# 52             +197.1    166066890.0               +172.7            55
# 53                -39     60906460.0                -35.6            54
# 54                +79     94583877.0                +75.7            52
# 55                  -    111455709.0                    -            51
# 56               -9.8     53837195.0                 -9.9            52
# 57              +81.4     59779023.0                +70.5            52
# 58                -27     35052113.0                  -24            48
# 59              -38.3     46118823.0                -35.5            45
# 60                  -     85074757.0                    -            37
# 61              +13.3     71534496.0                +13.9            41
# 62                -37     62796729.0                -36.5            35
#
#                                     top_release  week_no
# 0                      Avatar: The Way of Water       52
# 1                      Avatar: The Way of Water       52
# 2                      Avatar: The Way of Water       51
# 3                      Avatar: The Way of Water       51
# 4                      Avatar: The Way of Water       50
# 5                Black Panther: Wakanda Forever       49
# 6                Black Panther: Wakanda Forever       48
# 7                Black Panther: Wakanda Forever       47
# 8                Black Panther: Wakanda Forever       47
# 9                Black Panther: Wakanda Forever       47
# 10               Black Panther: Wakanda Forever       46
# 11               Black Panther: Wakanda Forever       45
# 12                                   Black Adam       44
# 13                                   Black Adam       43
# 14                                   Black Adam       42
# 15                               Halloween Ends       41
# 16                                        Smile       40
# 17                                        Smile       40
# 18                                        Smile       39
# 19                          Don't Worry Darling       38
# 20                               The Woman King       37
# 21                                    Barbarian       36
# 22                            Top Gun: Maverick       35
# 23                            Top Gun: Maverick       35
# 24                               The Invitation       34
# 25                Dragon Ball Super: Super Hero       33
# 26                                 Bullet Train       32
# 27                                 Bullet Train       31
# 28                      DC League of Super-Pets       30
# 29                                         Nope       29
# 30                       Thor: Love and Thunder       28
# 31                       Thor: Love and Thunder       27
# 32                     Minions: The Rise of Gru       26
# 33                     Minions: The Rise of Gru       26
# 34                                        Elvis       25
# 35                     Jurassic World: Dominion       24
# 36                     Jurassic World: Dominion       23
# 37                            Top Gun: Maverick       22
# 38                            Top Gun: Maverick       21
# 39                            Top Gun: Maverick       21
# 40  Doctor Strange in the Multiverse of Madness       20
# 41  Doctor Strange in the Multiverse of Madness       19
# 42  Doctor Strange in the Multiverse of Madness       18
# 43                                 The Bad Guys       17
# 44                                 The Bad Guys       16
# 45  Fantastic Beasts: The Secrets of Dumbledore       15
# 46  Fantastic Beasts: The Secrets of Dumbledore       15
# 47                         Sonic the Hedgehog 2       14
# 48                                      Morbius       13
# 49                                The Lost City       12
# 50                                   The Batman       11
# 51                                   The Batman       10
# 52                                   The Batman        9
# 53                                    Uncharted        8
# 54                                    Uncharted        7
# 55                                    Uncharted        7
# 56                            Death on the Nile        6
# 57                              Jackass Forever        5
# 58                      Spider-Man: No Way Home        4
# 59                      Spider-Man: No Way Home        3
# 60                                       Scream        2
# 61                                       Scream        2
# 62                      Spider-Man: No Way Home        1

# %%
#convert to date time date type
df['date'] = pd.to_datetime(df['date'], infer_datetime_format=True)
# Out:
# C:\Users\Yahdii\AppData\Local\Temp\ipykernel_23540\1932662626.py:2: UserWarning: Parsing '25/12/2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['date'] = pd.to_datetime(df['date'], infer_datetime_format=True)
# C:\Users\Yahdii\AppData\Local\Temp\ipykernel_23540\1932662626.py:2: UserWarning: Parsing '26/12/2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['date'] = pd.to_datetime(df['date'], infer_datetime_format=True)
# C:\Users\Yahdii\AppData\Local\Temp\ipykernel_23540\1932662626.py:2: UserWarning: Parsing '18/12/2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['date'] = pd.to_datetime(df['date'], infer_datetime_format=True)
# C:\Users\Yahdii\AppData\Local\Temp\ipykernel_23540\1932662626.py:2: UserWarning: Parsing '27/11/2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['date'] = pd.to_datetime(df['date'], infer_datetime_format=True)
# C:\Users\Yahdii\AppData\Local\Temp\ipykernel_23540\1932662626.py:2: UserWarning: Parsing '20/11/2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['date'] = pd.to_datetime(df['date'], infer_datetime_format=True)
# C:\Users\Yahdii\AppData\Local\Temp\ipykernel_23540\1932662626.py:2: UserWarning: Parsing '13/11/2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['date'] = pd.to_datetime(df['date'], infer_datetime_format=True)
# C:\Users\Yahdii\AppData\Local\Temp\ipykernel_23540\1932662626.py:2: UserWarning: Parsing '30/10/2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['date'] = pd.to_datetime(df['date'], infer_datetime_format=True)
# C:\Users\Yahdii\AppData\Local\Temp\ipykernel_23540\1932662626.py:2: UserWarning: Parsing '23/10/2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['date'] = pd.to_datetime(df['date'], infer_datetime_format=True)
# C:\Users\Yahdii\AppData\Local\Temp\ipykernel_23540\1932662626.py:2: UserWarning: Parsing '16/10/2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['date'] = pd.to_datetime(df['date'], infer_datetime_format=True)
# C:\Users\Yahdii\AppData\Local\Temp\ipykernel_23540\1932662626.py:2: UserWarning: Parsing '25/09/2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['date'] = pd.to_datetime(df['date'], infer_datetime_format=True)
# C:\Users\Yahdii\AppData\Local\Temp\ipykernel_23540\1932662626.py:2: UserWarning: Parsing '18/09/2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['date'] = pd.to_datetime(df['date'], infer_datetime_format=True)
# C:\Users\Yahdii\AppData\Local\Temp\ipykernel_23540\1932662626.py:2: UserWarning: Parsing '28/08/2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['date'] = pd.to_datetime(df['date'], infer_datetime_format=True)
# C:\Users\Yahdii\AppData\Local\Temp\ipykernel_23540\1932662626.py:2: UserWarning: Parsing '21/08/2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['date'] = pd.to_datetime(df['date'], infer_datetime_format=True)
# C:\Users\Yahdii\AppData\Local\Temp\ipykernel_23540\1932662626.py:2: UserWarning: Parsing '14/08/2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['date'] = pd.to_datetime(df['date'], infer_datetime_format=True)
# C:\Users\Yahdii\AppData\Local\Temp\ipykernel_23540\1932662626.py:2: UserWarning: Parsing '31/07/2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['date'] = pd.to_datetime(df['date'], infer_datetime_format=True)
# C:\Users\Yahdii\AppData\Local\Temp\ipykernel_23540\1932662626.py:2: UserWarning: Parsing '24/07/2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['date'] = pd.to_datetime(df['date'], infer_datetime_format=True)
# C:\Users\Yahdii\AppData\Local\Temp\ipykernel_23540\1932662626.py:2: UserWarning: Parsing '17/07/2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['date'] = pd.to_datetime(df['date'], infer_datetime_format=True)
# C:\Users\Yahdii\AppData\Local\Temp\ipykernel_23540\1932662626.py:2: UserWarning: Parsing '26/06/2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['date'] = pd.to_datetime(df['date'], infer_datetime_format=True)
# C:\Users\Yahdii\AppData\Local\Temp\ipykernel_23540\1932662626.py:2: UserWarning: Parsing '19/06/2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['date'] = pd.to_datetime(df['date'], infer_datetime_format=True)
# C:\Users\Yahdii\AppData\Local\Temp\ipykernel_23540\1932662626.py:2: UserWarning: Parsing '30/05/2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['date'] = pd.to_datetime(df['date'], infer_datetime_format=True)
# C:\Users\Yahdii\AppData\Local\Temp\ipykernel_23540\1932662626.py:2: UserWarning: Parsing '29/05/2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['date'] = pd.to_datetime(df['date'], infer_datetime_format=True)
# C:\Users\Yahdii\AppData\Local\Temp\ipykernel_23540\1932662626.py:2: UserWarning: Parsing '22/05/2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['date'] = pd.to_datetime(df['date'], infer_datetime_format=True)
# C:\Users\Yahdii\AppData\Local\Temp\ipykernel_23540\1932662626.py:2: UserWarning: Parsing '15/05/2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['date'] = pd.to_datetime(df['date'], infer_datetime_format=True)
# C:\Users\Yahdii\AppData\Local\Temp\ipykernel_23540\1932662626.py:2: UserWarning: Parsing '24/04/2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['date'] = pd.to_datetime(df['date'], infer_datetime_format=True)
# C:\Users\Yahdii\AppData\Local\Temp\ipykernel_23540\1932662626.py:2: UserWarning: Parsing '17/04/2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['date'] = pd.to_datetime(df['date'], infer_datetime_format=True)
# C:\Users\Yahdii\AppData\Local\Temp\ipykernel_23540\1932662626.py:2: UserWarning: Parsing '18/04/2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['date'] = pd.to_datetime(df['date'], infer_datetime_format=True)
# C:\Users\Yahdii\AppData\Local\Temp\ipykernel_23540\1932662626.py:2: UserWarning: Parsing '27/03/2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['date'] = pd.to_datetime(df['date'], infer_datetime_format=True)
# C:\Users\Yahdii\AppData\Local\Temp\ipykernel_23540\1932662626.py:2: UserWarning: Parsing '20/03/2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['date'] = pd.to_datetime(df['date'], infer_datetime_format=True)
# C:\Users\Yahdii\AppData\Local\Temp\ipykernel_23540\1932662626.py:2: UserWarning: Parsing '13/03/2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['date'] = pd.to_datetime(df['date'], infer_datetime_format=True)
# C:\Users\Yahdii\AppData\Local\Temp\ipykernel_23540\1932662626.py:2: UserWarning: Parsing '27/02/2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['date'] = pd.to_datetime(df['date'], infer_datetime_format=True)
# C:\Users\Yahdii\AppData\Local\Temp\ipykernel_23540\1932662626.py:2: UserWarning: Parsing '20/02/2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['date'] = pd.to_datetime(df['date'], infer_datetime_format=True)
# C:\Users\Yahdii\AppData\Local\Temp\ipykernel_23540\1932662626.py:2: UserWarning: Parsing '21/02/2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['date'] = pd.to_datetime(df['date'], infer_datetime_format=True)
# C:\Users\Yahdii\AppData\Local\Temp\ipykernel_23540\1932662626.py:2: UserWarning: Parsing '13/02/2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['date'] = pd.to_datetime(df['date'], infer_datetime_format=True)
# C:\Users\Yahdii\AppData\Local\Temp\ipykernel_23540\1932662626.py:2: UserWarning: Parsing '30/01/2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['date'] = pd.to_datetime(df['date'], infer_datetime_format=True)
# C:\Users\Yahdii\AppData\Local\Temp\ipykernel_23540\1932662626.py:2: UserWarning: Parsing '23/01/2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['date'] = pd.to_datetime(df['date'], infer_datetime_format=True)
# C:\Users\Yahdii\AppData\Local\Temp\ipykernel_23540\1932662626.py:2: UserWarning: Parsing '17/01/2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['date'] = pd.to_datetime(df['date'], infer_datetime_format=True)
# C:\Users\Yahdii\AppData\Local\Temp\ipykernel_23540\1932662626.py:2: UserWarning: Parsing '16/01/2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['date'] = pd.to_datetime(df['date'], infer_datetime_format=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 63 entries, 0 to 62
# Data columns (total 9 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   date                  63 non-null     datetime64[ns]
#  1   occasion              15 non-null     object
#  2   top10_gross           63 non-null     float64
#  3   top10_gross_change    63 non-null     object
#  4   overall_gross         63 non-null     float64
#  5   overall_gross_change  63 non-null     object
#  6   num_releases          63 non-null     int64
#  7   top_release           63 non-null     object
#  8   week_no               63 non-null     int64
# dtypes: datetime64[ns](1), float64(2), int64(2), object(4)
# memory usage: 4.6+ KB

# %% [markdown]
# ### Convert to CSV for PowerBI

# %%
df.to_csv('movie.csv')

# %%
pwd
# Out:
# 'C:\\Users\\Yahdii'
